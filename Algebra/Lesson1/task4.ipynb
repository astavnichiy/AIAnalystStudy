# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

lag = 0.1
x = np.arange(1, 10, lag)
y = np.cos(x)

x1 = np.arange(1, 10, lag)
y1 = np.cos(x1*2)

fig = plt.figure()
plt.plot(x, y)
plt.plot(x1, y1)
